jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(211).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(212).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(213).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(214).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(215).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(216).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(217).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(218).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(219).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(22).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(220).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(221).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(222).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(223).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(224).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(225).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(226).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(227).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(228).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(229).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(23).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(230).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(231).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(232).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(233).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(234).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(235).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(236).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(237).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(238).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(239).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(24).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(240).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(241).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(242).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(243).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(244).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(245).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(246).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(247).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(248).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(249).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(25).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(250).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(251).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(252).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(253).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(254).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(255).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(256).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(257).jpg
#   inflating: destination1/Data/train/NORMAL/NORMAL(258).jpg
# ...
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(788).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(789).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(79).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(790).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(791).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(792).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(793).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(794).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(795).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(796).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(797).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(798).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(799).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(8).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(80).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(800).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(801).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(802).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(803).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(804).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(805).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(806).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(807).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(808).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(809).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(81).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(810).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(811).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(812).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(813).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(814).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(815).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(816).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(817).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(818).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(819).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(82).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(820).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(821).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(822).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(823).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(824).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(825).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(826).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(827).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(828).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(829).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(83).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(830).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(831).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(832).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(833).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(834).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(835).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(836).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(837).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(838).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(839).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(84).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(840).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(841).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(842).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(843).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(844).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(845).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(846).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(847).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(848).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(849).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(85).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(850).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(851).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(852).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(853).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(854).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(855).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(856).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(857).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(858).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(859).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(86).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(860).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(861).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(862).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(863).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(864).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(865).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(866).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(867).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(868).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(869).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(87).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(870).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(871).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(872).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(873).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(874).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(875).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(876).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(877).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(878).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(879).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(88).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(880).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(881).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(882).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(883).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(884).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(885).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(886).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(887).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(888).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(889).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(89).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(890).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(891).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(892).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(893).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(894).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(895).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(896).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(897).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(898).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(899).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(9).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(90).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(900).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(901).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(902).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(903).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(904).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(905).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(906).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(907).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(908).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(909).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(91).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(910).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(911).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(912).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(913).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(914).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(915).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(916).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(917).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(918).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(919).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(92).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(920).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(921).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(922).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(923).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(924).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(925).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(926).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(927).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(928).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(929).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(93).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(930).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(931).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(932).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(933).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(934).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(935).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(936).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(937).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(938).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(939).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(94).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(940).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(941).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(942).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(943).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(944).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(945).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(946).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(947).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(948).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(949).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(95).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(950).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(951).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(952).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(953).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(954).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(955).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(956).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(957).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(958).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(959).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(96).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(960).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(961).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(962).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(963).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(964).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(965).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(966).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(967).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(968).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(969).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(97).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(970).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(971).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(972).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(973).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(974).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(975).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(976).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(977).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(978).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(979).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(98).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(980).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(981).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(982).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(983).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(984).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(985).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(986).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(987).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(988).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(989).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(99).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(990).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(991).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(992).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(993).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(994).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(995).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(996).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(997).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(998).jpg
#   inflating: destination1/Data/train/PNEUMONIA/PNEUMONIA(999).jpg

# %%
# !unzip /content/nih224folderwise-data.zip -d destination2

# %%
import os
import numpy as np
import shutil
import random


make_dir ='/content/destination1/Data'
root_dir = '/content/destination1/Data/train'
classes_dir = ['COVID19','NORMAL','PNEUMONIA']

val_ratio = 0.05

for cls in classes_dir:

  os.makedirs(make_dir +'/val/' + cls)


    # Creating partitions of the data after shuffeling
  src = root_dir + '/'+ cls # Folder to copy images from

  allFileNames = os.listdir(src)
  np.random.shuffle(allFileNames)
  train_FileNames, val_FileNames = np.split(np.array(allFileNames),
                                                              [int(len(allFileNames)* (1 - val_ratio))])


  train_FileNames = [src+'/'+ name for name in train_FileNames.tolist()]
  val_FileNames = [src+'/' + name for name in val_FileNames.tolist()]

  print('Total images: ', len(allFileNames))
  print('Training: ', len(train_FileNames))
  print('Validation: ', len(val_FileNames))

  # moving images

  for name in val_FileNames:
    shutil.move(name, make_dir +'/val/' + cls)
# Out:
# Total images:  460
# Training:  437
# Validation:  23
# Total images:  1266
# Training:  1202
# Validation:  64
# Total images:  3418
# Training:  3247
# Validation:  171

# %%
import tensorflow as tf
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
#train
train_datagen = ImageDataGenerator()
training_set = train_datagen.flow_from_directory('/content/destination1/Data/train',
                                                 target_size = (224, 224), class_mode='categorical', batch_size=32
                                                )
# Out:
# Found 4886 images belonging to 3 classes.

# %%
#test
test_datagen = ImageDataGenerator()
test_set = test_datagen.flow_from_directory('/content/destination1/Data/val',
                                                 target_size = (224, 224), class_mode='categorical', batch_size=8
                                                )
# Out:
# Found 258 images belonging to 3 classes.

# %%
#validation
val_datagen = ImageDataGenerator()
val_set = val_datagen.flow_from_directory('/content/destination1/Data/test',
                                            target_size = (224, 224), class_mode='categorical', batch_size=32
                                           )
# Out:
# Found 1288 images belonging to 3 classes.

# %%
model = Sequential()

model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))

model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))

model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))

model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))

model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

# %%
model.add(Flatten())
model.add(Dense(units=512,activation="relu"))
model.add(Dense(units=1024,activation="relu"))
model.add(Dense(units=3, activation="softmax"))

# %%
from keras.optimizers import Adam
opt = Adam(learning_rate=0.001)

# %%
model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               51380736
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 56,594,499
# Trainable params: 56,594,499
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
filepath = '/content/best_Model_weights.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
# early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, mode='auto')

# %%
results = model.fit(x=training_set, validation_data= val_set, epochs=25,callbacks=checkpoint)
# Out:
# Epoch 1/25
# 153/153 [==============================] - 202s 980ms/step - loss: 18.3527 - accuracy: 0.6500 - val_loss: 0.2694 - val_accuracy: 0.8960
#
# Epoch 00001: val_accuracy improved from -inf to 0.89596, saving model to /content/best_Model_weights.h5
# Epoch 2/25
# 153/153 [==============================] - 146s 955ms/step - loss: 0.2479 - accuracy: 0.9151 - val_loss: 0.2204 - val_accuracy: 0.9161
#
# Epoch 00002: val_accuracy improved from 0.89596 to 0.91615, saving model to /content/best_Model_weights.h5
# Epoch 3/25
# 153/153 [==============================] - 142s 928ms/step - loss: 0.1814 - accuracy: 0.9379 - val_loss: 0.2183 - val_accuracy: 0.9332
#
# Epoch 00003: val_accuracy improved from 0.91615 to 0.93323, saving model to /content/best_Model_weights.h5
# Epoch 4/25
# 153/153 [==============================] - 141s 920ms/step - loss: 0.1730 - accuracy: 0.9385 - val_loss: 0.1724 - val_accuracy: 0.9317
#
# Epoch 00004: val_accuracy did not improve from 0.93323
# Epoch 5/25
# 153/153 [==============================] - 141s 924ms/step - loss: 0.1301 - accuracy: 0.9551 - val_loss: 0.1498 - val_accuracy: 0.9495
#
# Epoch 00005: val_accuracy improved from 0.93323 to 0.94953, saving model to /content/best_Model_weights.h5
# Epoch 6/25
# 153/153 [==============================] - 141s 921ms/step - loss: 0.1312 - accuracy: 0.9531 - val_loss: 0.1588 - val_accuracy: 0.9488
#
# Epoch 00006: val_accuracy did not improve from 0.94953
# Epoch 7/25
# 153/153 [==============================] - 141s 921ms/step - loss: 0.1771 - accuracy: 0.9474 - val_loss: 0.2032 - val_accuracy: 0.9301
#
# Epoch 00007: val_accuracy did not improve from 0.94953
# Epoch 8/25
# 153/153 [==============================] - 142s 929ms/step - loss: 0.1176 - accuracy: 0.9591 - val_loss: 0.2808 - val_accuracy: 0.9425
#
# Epoch 00008: val_accuracy did not improve from 0.94953
# Epoch 9/25
# 153/153 [==============================] - 141s 922ms/step - loss: 0.1147 - accuracy: 0.9606 - val_loss: 0.2489 - val_accuracy: 0.9371
#
# Epoch 00009: val_accuracy did not improve from 0.94953
# Epoch 10/25
# 153/153 [==============================] - 141s 921ms/step - loss: 0.0690 - accuracy: 0.9743 - val_loss: 0.1725 - val_accuracy: 0.9410
#
# Epoch 00010: val_accuracy did not improve from 0.94953
# Epoch 11/25
# 153/153 [==============================] - 143s 935ms/step - loss: 0.0532 - accuracy: 0.9798 - val_loss: 0.1819 - val_accuracy: 0.9464
#
# Epoch 00011: val_accuracy did not improve from 0.94953
# Epoch 12/25
# 153/153 [==============================] - 141s 922ms/step - loss: 0.0710 - accuracy: 0.9767 - val_loss: 0.2495 - val_accuracy: 0.9379
#
# Epoch 00012: val_accuracy did not improve from 0.94953
# Epoch 13/25
# 153/153 [==============================] - 143s 932ms/step - loss: 0.0505 - accuracy: 0.9805 - val_loss: 0.2890 - val_accuracy: 0.9387
#
# Epoch 00013: val_accuracy did not improve from 0.94953
# Epoch 14/25
# 153/153 [==============================] - 141s 925ms/step - loss: 0.0592 - accuracy: 0.9793 - val_loss: 0.3366 - val_accuracy: 0.9092
#
# Epoch 00014: val_accuracy did not improve from 0.94953
# Epoch 15/25
# 153/153 [==============================] - 142s 925ms/step - loss: 0.2134 - accuracy: 0.9259 - val_loss: 0.1476 - val_accuracy: 0.9480
#
# Epoch 00015: val_accuracy did not improve from 0.94953
# Epoch 16/25
# 153/153 [==============================] - 156s 1s/step - loss: 0.0641 - accuracy: 0.9803 - val_loss: 0.2553 - val_accuracy: 0.9402
#
# Epoch 00016: val_accuracy did not improve from 0.94953
# Epoch 17/25
# 153/153 [==============================] - 141s 924ms/step - loss: 0.0362 - accuracy: 0.9881 - val_loss: 0.2637 - val_accuracy: 0.9418
#
# Epoch 00017: val_accuracy did not improve from 0.94953
# Epoch 18/25
# 153/153 [==============================] - 142s 924ms/step - loss: 0.1423 - accuracy: 0.9639 - val_loss: 0.4576 - val_accuracy: 0.9371
#
# Epoch 00018: val_accuracy did not improve from 0.94953
# Epoch 19/25
# 153/153 [==============================] - 141s 921ms/step - loss: 0.0624 - accuracy: 0.9810 - val_loss: 0.3107 - val_accuracy: 0.9332
#
# Epoch 00019: val_accuracy did not improve from 0.94953
# Epoch 20/25
# 153/153 [==============================] - 141s 923ms/step - loss: 0.0261 - accuracy: 0.9898 - val_loss: 0.3508 - val_accuracy: 0.9387
#
# Epoch 00020: val_accuracy did not improve from 0.94953
# Epoch 21/25
# 153/153 [==============================] - 141s 923ms/step - loss: 0.0254 - accuracy: 0.9921 - val_loss: 0.3745 - val_accuracy: 0.9387
#
# Epoch 00021: val_accuracy did not improve from 0.94953
# Epoch 22/25
# 153/153 [==============================] - 142s 925ms/step - loss: 0.0176 - accuracy: 0.9959 - val_loss: 0.3061 - val_accuracy: 0.9457
#
# Epoch 00022: val_accuracy did not improve from 0.94953
# Epoch 23/25
# 153/153 [==============================] - 141s 922ms/step - loss: 0.0472 - accuracy: 0.9853 - val_loss: 0.3391 - val_accuracy: 0.9262
#
# Epoch 00023: val_accuracy did not improve from 0.94953
# Epoch 24/25
# 153/153 [==============================] - 142s 928ms/step - loss: 0.0680 - accuracy: 0.9785 - val_loss: 0.2797 - val_accuracy: 0.9457
#
# Epoch 00024: val_accuracy did not improve from 0.94953
# Epoch 25/25
# 153/153 [==============================] - 141s 922ms/step - loss: 0.0169 - accuracy: 0.9935 - val_loss: 0.3167 - val_accuracy: 0.9394
#
# Epoch 00025: val_accuracy did not improve from 0.94953

# %% [markdown]
# # Model accuracy and loss graphs

# %%
import matplotlib.pyplot as plt
plt.plot(results.history["accuracy"])
plt.plot(results.history['val_accuracy'])
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()

# %% [markdown]
# # Graphical confusion matrix

# %%
import matplotlib.pyplot as plt
import itertools

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):

    """

    This function prints and plots the confusion matrix.

    Normalization can be applied by setting `normalize=True`.

    """

    plt.figure(figsize=(10,10))


    plt.imshow(cm, interpolation='nearest', cmap=cmap)

    plt.title(title)

    plt.colorbar()


    tick_marks = np.arange(len(classes))

    plt.xticks(tick_marks, classes, rotation=45)

    plt.yticks(tick_marks, classes)


    if normalize:

        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        cm = np.around(cm, decimals=2)

        cm[np.isnan(cm)] = 0.0

        print("Normalized confusion matrix")

    else:

        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):

        plt.text(j, i, cm[i, j],

                 horizontalalignment="center",

                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()

    plt.ylabel('True label')

    plt.xlabel('Predicted label')

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

target_names = []

for key in training_set.class_indices:

    target_names.append(key)


print(target_names)


test_steps_per_epoch = np.math.ceil(test_set.samples / test_set.batch_size)

Y_pred = model.predict(test_set, steps=test_steps_per_epoch)

y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')

cm = confusion_matrix(test_set.classes, y_pred)

plot_confusion_matrix(cm, target_names, title='Confusion Matrix')
# Out:
# ['COVID19', 'NORMAL', 'PNEUMONIA']
# Confusion Matrix
# Normalized confusion matrix

# %% [markdown]
# # Classification report

# %%
test_steps_per_epoch = np.math.ceil(test_set.samples / test_set.batch_size)

predictions = model.predict(test_set, steps=test_steps_per_epoch)
# Get most likely class
predicted_classes = np.argmax(predictions, axis=-1)
true_classes = test_set.classes
class_labels = list(test_set.class_indices.keys())

# %%
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      COVID19       0.04      0.04      0.04        23
#       NORMAL       0.34      0.36      0.35        64
#    PNEUMONIA       0.69      0.67      0.68       171
#
#     accuracy                           0.53       258
#    macro avg       0.36      0.36      0.36       258
# weighted avg       0.54      0.53      0.54       258

# %% [markdown]
# # Saving and Loading the model for prediction

# %%
from keras.models import model_from_json
from keras.models import load_model

# %%
model_json = model.to_json()
with open("/content/best_Model_weights.json", "w") as json_file:
    json_file.write(model_json)

# %%
json_file = open('/content/best_Model_weights.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights('best_Model_weights.h5')

# %%
# from keras.models import model_from_json
# from keras.models import load_model

# # serialize model to JSON
# model_json = model.to_json()
# with open("best_Model_weights.json", "w") as json_file:
#     json_file.write(model_json)

# # serialize weights to HDF5
# model.save_weights("best_Model_weights.h5")

# %%
# # load json and create model
# json_file = open('best_Model_weights.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# loaded_model = model_from_json(loaded_model_json)

# # load weights into new model
# loaded_model.load_weights("best_Model_weights.h5")
# print("Loaded model from disk")

# loaded_model.save('best_Model_weights.hdf5')
# loaded_model=load_model('best_Model_weights.hdf5')
# Out:
# Loaded model from disk
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Deploying the model to Predict a single sample.

# %%
# from keras.preprocessing import image
# img = image.load_img("......",target_size=(224,224))
# img = np.asarray(img)

# img = np.expand_dims(img, axis=0)
# loaded_model.predict(img)

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('......', target_size = (224, 224))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 1)
predicted_classes= np.argmax(loaded_model.predict(test_image), axis=1)

result = loaded_model.predict(test_image)
test_set.class_indices
if result[0][0][0] == 1:
  prediction = 'Normal'
elif result[0][1][0] ==1:
  prediction = 'PNEUMONIA'
else:
  prediction = 'Covid'

# %%
print(prediction)
print(result)

# %% [markdown]
# # the code for the 4-class dataset and its organization.

# %%
# !kaggle datasets download -d pratik2901/multiclass-weather-dataset #4-class dataset
mkdir destination2
# !unzip /content/multiclass-weather-dataset.zip -d destination2

# %%
import os
import numpy as np
import shutil
import random
root_dir = '/content/destination2/Multi-class Weather Dataset/' # data root path
classes_dir = ['Cloudy', 'Rain', 'Shine', 'Sunrise'] #total labels

val_ratio = 0.15
test_ratio = 0.05

for cls in classes_dir:
    os.makedirs(root_dir +'train/' + cls)
    os.makedirs(root_dir +'val/' + cls)
    os.makedirs(root_dir +'test/' + cls)

    # Creating partitions of the data after shuffeling
    src = root_dir + cls # Folder to copy images from

    allFileNames = os.listdir(src)
    np.random.shuffle(allFileNames)
    train_FileNames, val_FileNames, test_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)* (1 - (val_ratio + test_ratio))), 
                                                           int(len(allFileNames)* (1 - test_ratio))])


    train_FileNames = [src+'/'+ name for name in train_FileNames.tolist()]
    val_FileNames = [src+'/' + name for name in val_FileNames.tolist()]
    test_FileNames = [src+'/' + name for name in test_FileNames.tolist()]

    print('Total images: ', len(allFileNames))
    print('Training: ', len(train_FileNames))
    print('Validation: ', len(val_FileNames))
    print('Testing: ', len(test_FileNames))

    # Copy-pasting images
    for name in train_FileNames:
      shutil.copy(name, root_dir +'train/' + cls)

    for name in val_FileNames:
      shutil.copy(name, root_dir +'val/' + cls)
      
    for name in test_FileNames:
      shutil.copy(name, root_dir +'test/' + cls)

# %%
train_datagen1 = ImageDataGenerator()
training_set1 = train_datagen1.flow_from_directory('/content/destination2/Multi-class Weather Dataset/train',
                                                 target_size = (224, 224), class_mode='categorical', batch_size=8
                                                )
# Out:
# Found 899 images belonging to 4 classes.

# %%
val_datagen1 = ImageDataGenerator()
val_set1 = val_datagen1.flow_from_directory('/content/destination2/Multi-class Weather Dataset/val',
                                            target_size = (224, 224), class_mode='categorical', batch_size=8
                                           )
# Out:
# Found 169 images belonging to 4 classes.

# %%
test_datagen1 = ImageDataGenerator()
test_set1 = test_datagen1.flow_from_directory('/content/destination4/Multi-class Weather Dataset/test',
                                            target_size = (224, 224), class_mode='categorical',batch_size=4
                                           )
# Out:
# Found 57 images belonging to 4 classes.

# %%
loaded_model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
checkpoint_filepath = 'bff.h5'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(checkpoint_filepath,save_best_only=True, monitor='val_accuracy')

# %% [markdown]
# # Training a model trainded on 3-class dataset on a 4-class dataset (still  being prepared and worked on)

# %%
# results1 = loaded_model.fit(x=training_set1, validation_data= val_set1, epochs=40,callbacks=[model_checkpoint_callback])
